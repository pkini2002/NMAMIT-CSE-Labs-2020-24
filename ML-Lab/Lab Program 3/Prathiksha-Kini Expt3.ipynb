# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

sns.set_theme(color_codes = True)
warnings.simplefilter("ignore")

# %%
df=pd.read_csv("Clean_Dataset.csv")
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %% [markdown]
# ## Data Visualization

# %%
sns.countplot(data=df,x="airline")
# Out:
# <AxesSubplot:xlabel='airline', ylabel='count'>

# %%
sns.countplot(data=df,x="source_city")
# Out:
# <AxesSubplot:xlabel='source_city', ylabel='count'>

# %%
sns.countplot(data=df,x="departure_time")
# Out:
# <AxesSubplot:xlabel='departure_time', ylabel='count'>

# %%
sns.countplot(data=df,x="stops")
# Out:
# <AxesSubplot:xlabel='stops', ylabel='count'>

# %%
sns.countplot(data=df,x="arrival_time")
# Out:
# <AxesSubplot:xlabel='arrival_time', ylabel='count'>

# %%
sns.countplot(data=df,x="destination_city")
# Out:
# <AxesSubplot:xlabel='destination_city', ylabel='count'>

# %%
sns.countplot(data=df,x="class")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %% [markdown]
# ## Business Class

# %%
df2=pd.read_csv("business.csv")
df2.head()
# Out:
#          date    airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  Air India      AI       868    18:00  Delhi    02h 00m
# 1  11-02-2022  Air India      AI       624    19:00  Delhi    02h 15m
# 2  11-02-2022  Air India      AI       531    20:00  Delhi    24h 45m
# 3  11-02-2022  Air India      AI       839    21:25  Delhi    26h 30m
# 4  11-02-2022  Air India      AI       544    17:15  Delhi    06h 40m
#
#                                                 stop arr_time      to   price
# 0                                          non-stop     20:00  Mumbai  25,612
# 1                                          non-stop     21:15  Mumbai  25,612
# 2  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45  Mumbai  42,220
# 3  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  44,450
# 4  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  46,690

# %%
sns.countplot(data=df2,x="airline")
# Out:
# <AxesSubplot:xlabel='airline', ylabel='count'>

# %%
sns.countplot(data=df2,x="ch_code")
# Out:
# <AxesSubplot:xlabel='ch_code', ylabel='count'>

# %%
sns.countplot(data=df2,x="from",hue="to")
# Out:
# <AxesSubplot:xlabel='from', ylabel='count'>

# %%
df2.isnull().sum()
# Out:
# date          0
# airline       0
# ch_code       0
# num_code      0
# dep_time      0
# from          0
# time_taken    0
# stop          0
# arr_time      0
# to            0
# price         0
# dtype: int64

# %% [markdown]
# ## Economy class

# %%
df3=pd.read_csv("economy.csv")
df3.head()
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price
# 0  non-stop     21:05  Mumbai  5,953
# 1  non-stop     08:40  Mumbai  5,953
# 2  non-stop     06:35  Mumbai  5,956
# 3  non-stop     12:35  Mumbai  5,955
# 4  non-stop     11:10  Mumbai  5,955

# %%
sns.countplot(data=df3,x="airline")
# Out:
# <AxesSubplot:xlabel='airline', ylabel='count'>

# %%
sns.countplot(data=df3,x="ch_code")
# Out:
# <AxesSubplot:xlabel='ch_code', ylabel='count'>

# %%
sns.countplot(data=df3,x="from",hue="to")
# Out:
# <AxesSubplot:xlabel='from', ylabel='count'>

# %%
df3.isnull().sum()
# Out:
# date          0
# airline       0
# ch_code       0
# num_code      0
# dep_time      0
# from          0
# time_taken    0
# stop          0
# arr_time      0
# to            0
# price         0
# dtype: int64

# %% [markdown]
# ## Converting textual data to numerical format

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

df['airline']= label_encoder.fit_transform(df['airline'])
df['airline'].unique()

df['flight']= label_encoder.fit_transform(df['flight'])
df['flight'].unique()

df['source_city']= label_encoder.fit_transform(df['source_city'])
df['source_city'].unique()

df['departure_time']= label_encoder.fit_transform(df['departure_time'])
df['departure_time'].unique()

df['stops']= label_encoder.fit_transform(df['stops'])
df['stops'].unique()

df['arrival_time']= label_encoder.fit_transform(df['arrival_time'])
df['arrival_time'].unique()

df['destination_city']= label_encoder.fit_transform(df['destination_city'])
df['destination_city'].unique()

df['class']= label_encoder.fit_transform(df['class'])
df['class'].unique()
# Out:
# array([1, 0])

# %%
df.head()
# Out:
#    Unnamed: 0  airline  flight  source_city  departure_time  stops  \
# 0           0        4    1408            2               2      2
# 1           1        4    1387            2               1      2
# 2           2        0    1213            2               1      2
# 3           3        5    1559            2               4      2
# 4           4        5    1549            2               4      2
#
#    arrival_time  destination_city  class  duration  days_left  price
# 0             5                 5      1      2.17          1   5953
# 1             4                 5      1      2.33          1   5953
# 2             1                 5      1      2.17          1   5956
# 3             0                 5      1      2.25          1   5955
# 4             4                 5      1      2.33          1   5955

# %%
df2['date']= label_encoder.fit_transform(df2['date'])
df2['date'].unique()

df2['airline']= label_encoder.fit_transform(df2['airline'])
df2['airline'].unique()

df2['ch_code']= label_encoder.fit_transform(df2['ch_code'])
df2['ch_code'].unique()

df2['dep_time']= label_encoder.fit_transform(df2['dep_time'])
df2['dep_time'].unique()

df2['from']= label_encoder.fit_transform(df2['from'])
df2['from'].unique()

df2['time_taken']= label_encoder.fit_transform(df2['time_taken'])
df2['time_taken'].unique()

df2['stop']= label_encoder.fit_transform(df2['stop'])
df2['stop'].unique()

df2['arr_time']= label_encoder.fit_transform(df2['arr_time'])
df2['arr_time'].unique()

df2['to']= label_encoder.fit_transform(df2['to'])
df2['to'].unique()

df2['price']= label_encoder.fit_transform(df2['price'])
df2['price'].unique()
# Out:
# array([ 106,  389,  450, ..., 1709,   72, 1814])

# %%
df2.head()
# Out:
#    date  airline  ch_code  num_code  dep_time  from  time_taken  stop  \
# 0    10        0        0       868       121     2          12    24
# 1    10        0        0       624       131     2          15    24
# 2    10        0        0       531       140     2         282     0
# 3    10        0        0       839       154     2         303     0
# 4    10        0        0       544       113     2          65     0
#
#    arr_time  to  price
# 0       131   5    106
# 1       146   5    106
# 2       140   5    389
# 3       175   5    450
# 4       175   5    525

# %%
df3['date']= label_encoder.fit_transform(df3['date'])
df3['date'].unique()

df3['airline']= label_encoder.fit_transform(df3['airline'])
df3['airline'].unique()

df3['ch_code']= label_encoder.fit_transform(df3['ch_code'])
df3['ch_code'].unique()

df3['dep_time']= label_encoder.fit_transform(df3['dep_time'])
df3['dep_time'].unique()

df3['from']= label_encoder.fit_transform(df3['from'])
df3['from'].unique()

df3['time_taken']= label_encoder.fit_transform(df3['time_taken'])
df3['time_taken'].unique()

df3['stop']= label_encoder.fit_transform(df3['stop'])
df3['stop'].unique()

df3['arr_time']= label_encoder.fit_transform(df3['arr_time'])
df3['arr_time'].unique()

df3['to']= label_encoder.fit_transform(df3['to'])
df3['to'].unique()

df3['price']= label_encoder.fit_transform(df3['price'])
df3['price'].unique()
# Out:
# array([6924, 6927, 6926, ..., 3978, 6737, 7416])

# %%
df3.head()
# Out:
#    date  airline  ch_code  num_code  dep_time  from  time_taken  stop  \
# 0    10        4        6      8709       190     2          16    36
# 1    10        4        6      8157        40     2          18    36
# 2    10        1        4       764        17     2          16    36
# 3    10        7        7       995        88     2          17    36
# 4    10        7        7       963        70     2          18    36
#
#    arr_time  to  price
# 0       230   5   6924
# 1        81   5   6924
# 2        56   5   6927
# 3       128   5   6926
# 4       111   5   6926

# %% [markdown]
# ## Displaying impurites using BoxPlot

# %%
sns.boxplot(x=df["airline"])
# Out:
# <AxesSubplot:xlabel='airline'>

# %%
sns.boxplot(x=df["flight"])
# Out:
# <AxesSubplot:xlabel='flight'>

# %%
sns.boxplot(x=df2["date"])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sns.boxplot(x=df2["ch_code"])
# Out:
# <AxesSubplot:xlabel='ch_code'>

# %%
sns.boxplot(x=df3["date"])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sns.boxplot(x=df3["airline"])
# Out:
# <AxesSubplot:xlabel='airline'>

# %%
import scipy.stats as stats
z= np.abs(stats.zscore(df))
data_clean1 = df[(z<3).all(axis=1)]
data_clean1.shape
# Out:
# (298829, 12)

# %%
z= np.abs(stats.zscore(df2))
data_clean2 = df2[(z<3).all(axis=1)]
data_clean2.shape
# Out:
# (92894, 11)

# %%
z= np.abs(stats.zscore(df3))
data_clean3 = df3[(z<3).all(axis=1)]
data_clean3.shape
# Out:
# (200061, 11)

# %%
sns.heatmap(data_clean1.corr(),fmt=".2g")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data_clean2.corr(),fmt=".2g")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data_clean3.corr(),fmt=".2g")
# Out:
# <AxesSubplot:>

# %%
corr = data_clean1[data_clean1.columns[1:]].corr()['price'][:-1]
plt.plot(corr)
plt.xticks(rotation=90)
plt.show()

# %%
corr = data_clean2[data_clean2.columns[1:]].corr()['price'][:-1]
plt.plot(corr)
plt.xticks(rotation=90)
plt.show()

# %%
corr = data_clean3[data_clean3.columns[1:]].corr()['price'][:-1]
plt.plot(corr)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Training the models using ML algorithms

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import accuracy_score
from sklearn import metrics
import math

# %% [markdown]
# ## Splitting and training the Cleaned dataset

# %%
X = df.drop('price', axis=1)
y = df['price']

dtree = DecisionTreeRegressor(random_state=0)
dtree.fit(X_train, y_train)
y_pred = dtree.predict(X_test)

mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 67.95197347309873
# MSE is 41091.959300459945
# R2 score is 0.7936281336996656
# RMSE score is 202.71151743416047

# %%
rf = RandomForestRegressor(random_state=0)
rf.fit(X_train, y_train)
RandomForestRegressor(random_state=0)

y_pred = rf.predict(X_test)
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 72.55954204931518
# MSE is 27163.796763586026
# R2 score is 0.8635780933949896
# RMSE score is 164.81443129649182

# %%
ada = AdaBoostRegressor(random_state=0)
ada.fit(X_train, y_train)

AdaBoostRegressor(random_state=0)
y_pred = ada.predict(X_test)
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
mse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 268.69320721855786
# MSE is 349.10969384615936
# R2 score is 0.38790693532677356
# RMSE score is 164.81443129649182

# %% [markdown]
# ## Splitting and training the Business class dataset

# %%
X = df2.drop('price', axis=1)
y = df2['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=0)

# %%
dtree = DecisionTreeRegressor(random_state=0)
dtree.fit(X_train, y_train)
y_pred = dtree.predict(X_test)

mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 67.95197347309873
# MSE is 41091.959300459945
# R2 score is 0.7936281336996656
# RMSE score is 202.71151743416047

# %%
rf = RandomForestRegressor(random_state=0)
rf.fit(X_train, y_train)
RandomForestRegressor(random_state=0)

y_pred = rf.predict(X_test)
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 72.55954204931518
# MSE is 27163.796763586026
# R2 score is 0.8635780933949896
# RMSE score is 164.81443129649182

# %%
ada = AdaBoostRegressor(random_state=0)
ada.fit(X_train, y_train)

AdaBoostRegressor(random_state=0)
y_pred = ada.predict(X_test)
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
mse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 268.69320721855786
# MSE is 349.10969384615936
# R2 score is 0.38790693532677356
# RMSE score is 164.81443129649182

# %% [markdown]
# ## Splitting and training the Economy class dataset

# %%
X = df3.drop('price', axis=1)
y = df3['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=0)

# %%
dtree = DecisionTreeRegressor(random_state=0)
dtree.fit(X_train, y_train)
y_pred = dtree.predict(X_test)

mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 829.0906762584128
# MSE is 3567181.8623700277
# R2 score is 0.3840512381261246
# RMSE score is 1888.6984572371598

# %%
rf = RandomForestRegressor(random_state=0)
rf.fit(X_train, y_train)
RandomForestRegressor(random_state=0)

y_pred = rf.predict(X_test)
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 798.9639744841458
# MSE is 2038290.7002207073
# R2 score is 0.6480463622042978
# RMSE score is 1427.6871857030542

# %%
ada = AdaBoostRegressor(random_state=0)
ada.fit(X_train, y_train)

AdaBoostRegressor(random_state=0)
y_pred = ada.predict(X_test)
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
mse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 1851.8572709869886
# MSE is 2318.967256944394
# R2 score is 0.07144299935619214
# RMSE score is 1427.6871857030542
